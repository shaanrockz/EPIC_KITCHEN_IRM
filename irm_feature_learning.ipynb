# %%
import numpy as np
import torch
from torch.utils.data import DataLoader, Dataset
import pandas as pd

# %%
class EPIC(Dataset):
    def __init__(self, data_path, p_id=None, df=None, train_batch_size=None):
        super().__init__()
        if p_id is not None:
            idd = df.index[df['participant_id'] == p_id].tolist()
            if len(idd)< train_batch_size:
                self.hasData = False
            else:
                self.hasData = True
            if 0 in idd:
                idd.remove(0)
            data = np.load(data_path)
            self.verb = data[idd, -2]
            self.noun = data[idd, -1]
            self.data = data[idd, :-2]
        else:
            data = np.load(data_path)
            self.verb = data[1:, -2]
            self.noun = data[1:, -1]
            self.data = data[1:, :-2]
    
    def __len__(self):
        return np.shape(self.data)[0]
    
    def __getitem__(self, idx):
        verb = np.squeeze(self.verb[idx])
        noun = np.squeeze(self.noun[idx])

        return {
                "data":     torch.tensor(np.expand_dims(np.squeeze(self.data[idx,:]), 0)).float(), 
                "verb_id":  torch.tensor(np.expand_dims(verb, 1)).long(), 
                "noun_id":  torch.tensor(np.expand_dims(noun, 1)).long()
                }

class IRM(torch.nn.Module):
    def __init__(self, num_class_verb, num_class_noun):
        super().__init__()
        self.verb_fc = torch.nn.Linear(2048, num_class_verb)
        self.noun_fc = torch.nn.Linear(2048, num_class_noun)
    
    def forward(self, x):
        return {"verb_out": self.verb_fc(x), "noun_out": self.noun_fc(x)}

# %%
torch.manual_seed(786)

df = pd.read_csv("EPIC_train_action_labels.csv", nrows=23192)
p_ids = list(set(df["participant_id"].tolist()))

d = np.load("train-unseen.npy")
weight_verb = [0]*125
weight_noun = [0]*352
val_verb, weight_verb_ = np.unique(d[:,-2], return_counts=True)
val_noun, weight_noun_ = np.unique(d[:,-1], return_counts=True)

for i in range(len(val_verb)):
    weight_verb[int(val_verb[i])] = weight_verb_[i]

for i in range(len(val_noun)):
    weight_noun[int(val_noun[i])] = weight_noun_[i]

weight_verb = [weight_verb[i]/np.shape(d)[0] for i in range(len(weight_verb))]
weight_noun = [weight_noun[i]/np.shape(d)[0] for i in range(len(weight_noun))]

train_batch_size = 100
train_loaders = []
for i in range(len(p_ids)):
    dataset_train = EPIC("train-unseen.npy", p_ids[i], df, train_batch_size)
    if dataset_train.hasData:
        train_loaders.append(DataLoader(dataset_train, batch_size=100, shuffle=True, drop_last=True))

dataset_ver= EPIC("train-unseen.npy")
ver_loader = DataLoader(dataset_ver, batch_size=200, shuffle=False, drop_last=True)

dataset_val = EPIC("val-unseen.npy")
val_loader = DataLoader(dataset_val, batch_size=200, shuffle=False, drop_last=True)

model = IRM(125, 352)
# model = IRM(2, 2)

dummy_w = torch.nn.Parameter(torch.tensor([1.0])) 
opt = torch.optim.SGD(model.parameters(), lr=1e-2)

def compute_penalty(losses, dummy):
  g1 = torch.autograd.grad(losses[0::2].mean(), dummy, create_graph=True)[0]
  g2 = torch.autograd.grad(losses[1::2].mean(), dummy, create_graph=True)[0]
  return (g1 * g2).sum()

ce_verb = torch.nn.CrossEntropyLoss(weight=torch.tensor(weight_verb).float(), reduction="none")
ce_noun = torch.nn.CrossEntropyLoss(weight=torch.tensor(weight_noun).float(), reduction="none")

for epoch in range(100):
    print("Epoch : "+str(epoch+1))
    model.train()
    _loaders = [iter(x) for x in train_loaders]

    err_verb = 0
    err_noun = 0
    counter = 0
    while True:
        verb_loss = 0
        noun_loss = 0
        verb_penalty = 0
        noun_penalty = 0
        weight_norms = 0
        penalty_factor = 0.15
        envs = 0
        for i in range(len(_loaders)):
            try:
                sample_batch = next(_loaders[i])
            except:
                continue
            envs+=1
            data = sample_batch["data"]
            verb = sample_batch["verb_id"]
            noun = sample_batch["noun_id"]

            # if torch.isnan(data).any():
            #     print("Nan Here")

            _out = model(data)
            verb_out = _out["verb_out"]
            noun_out = _out["noun_out"]
            
            verb_loss_ = ce_verb(verb_out.squeeze()*dummy_w, verb.view(-1))
            noun_loss_= ce_noun(noun_out.squeeze()*dummy_w, noun.view(-1))

            weight_norm = torch.as_tensor(0.0)

            for w in model.parameters():
                weight_norm += w.norm().pow(2)
            weight_norms += weight_norm

            if epoch > 50:
                verb_penalty += compute_penalty(verb_loss_, dummy_w)
                noun_penalty += compute_penalty(noun_loss_, dummy_w)

            verb_loss += verb_loss_.mean()
            noun_loss += noun_loss_.mean()
        
        if envs == 1:
            break
        else:
            counter+=envs
        # err_verb = verb_loss.item()+verb_penalty.item()
        # err_noun = noun_loss.item()+noun_penalty.item()
        err_verb += verb_loss.item()
        err_noun += noun_loss.item()

        opt.zero_grad()
        (penalty_factor*(verb_loss+noun_loss)+(verb_penalty+noun_penalty)+0.005*weight_norms).backward()
        torch.nn.utils.clip_grad_norm(model.parameters(), 20)
        opt.step()

    print(err_verb/counter)
    print(err_noun/counter)
    
    model.eval()

    with torch.no_grad():
        correct_verb = 0
        correct_noun = 0
        correct_action = 0
        count = 0
        for idx, sample_batch in enumerate(ver_loader):
            data = sample_batch["data"]
            verb = sample_batch["verb_id"]
            noun = sample_batch["noun_id"]

            _out = model(data)
            verb_out = _out["verb_out"]
            noun_out = _out["noun_out"]

            pred_class_verb = torch.argmax(verb_out, dim=2)

            correct_verb += (
                (verb.view(-1) == pred_class_verb.view(-1))
                .float()
                .sum()
                .item()
            )

            pred_class_noun = torch.argmax(noun_out, dim=2)

            correct_noun += (
                (noun.view(-1) == pred_class_noun.view(-1))
                .float()
                .sum()
                .item()
            )

            # Accuracy Action
            correct_action += (
                (
                    (verb.view(-1) == pred_class_verb.view(-1)).int()
                    & (noun.view(-1) == pred_class_noun.view(-1)).int()
                )
                .float()
                .sum()
                .item()
            )

            count += 200
        print("Train Accuracy/Verb(Top 1)", correct_verb / count)
        print("Train Accuracy/Noun(Top 1)", correct_noun / count)
        print("Train Accuracy/Action(Top 1)", correct_action / count)



        correct_verb = 0
        correct_noun = 0
        correct_action = 0
        count = 0
        for idx, sample_batch in enumerate(val_loader):
            data = sample_batch["data"]
            verb = sample_batch["verb_id"]
            noun = sample_batch["noun_id"]

            _out = model(data)
            verb_out = _out["verb_out"]
            noun_out = _out["noun_out"]

            pred_class_verb = torch.argmax(verb_out, dim=2)

            correct_verb += (
                (verb.view(-1) == pred_class_verb.view(-1))
                .float()
                .sum()
                .item()
            )

            pred_class_noun = torch.argmax(noun_out, dim=2)

            correct_noun += (
                (noun.view(-1) == pred_class_noun.view(-1))
                .float()
                .sum()
                .item()
            )

            # Accuracy Action
            correct_action += (
                (
                    (verb.view(-1) == pred_class_verb.view(-1)).int()
                    & (noun.view(-1) == pred_class_noun.view(-1)).int()
                )
                .float()
                .sum()
                .item()
            )

            count += 200
        print("Val Accuracy/Verb(Top 1)", correct_verb / count)
        print("Val Accuracy/Noun(Top 1)", correct_noun / count)
        print("Val Accuracy/Action(Top 1)", correct_action / count)
# Out:
# al Accuracy/Verb(Top 1) 0.28365384615384615
# Val Accuracy/Noun(Top 1) 0.11365384615384615
# Val Accuracy/Action(Top 1) 0.026153846153846153
# Epoch : 40
# 0.1473712130290706
# 0.07448281260525308
# Train Accuracy/Verb(Top 1) 0.38073913043478264
# Train Accuracy/Noun(Top 1) 0.12578260869565216
# Train Accuracy/Action(Top 1) 0.0388695652173913
# Val Accuracy/Verb(Top 1) 0.28442307692307695
# Val Accuracy/Noun(Top 1) 0.11384615384615385
# Val Accuracy/Action(Top 1) 0.02576923076923077
# Epoch : 41
# 0.1466542488191186
# 0.07384980379081355
# Train Accuracy/Verb(Top 1) 0.38130434782608696
# Train Accuracy/Noun(Top 1) 0.12565217391304348
# Train Accuracy/Action(Top 1) 0.0388695652173913
# Val Accuracy/Verb(Top 1) 0.28365384615384615
# Val Accuracy/Noun(Top 1) 0.11403846153846153
# Val Accuracy/Action(Top 1) 0.025961538461538463
# Epoch : 42
# 0.1462756841647916
# 0.07375104492757378
# Train Accuracy/Verb(Top 1) 0.382
# Train Accuracy/Noun(Top 1) 0.1254782608695652
# Train Accuracy/Action(Top 1) 0.03904347826086957
# Val Accuracy/Verb(Top 1) 0.2840384615384615
# Val Accuracy/Noun(Top 1) 0.11365384615384615
# Val Accuracy/Action(Top 1) 0.025961538461538463
# Epoch : 43
# 0.14569466811854664
# 0.07339004837885135
# Train Accuracy/Verb(Top 1) 0.3824782608695652
# Train Accuracy/Noun(Top 1) 0.12543478260869564
# Train Accuracy/Action(Top 1) 0.03891304347826087
# Val Accuracy/Verb(Top 1) 0.2851923076923077
# Val Accuracy/Noun(Top 1) 0.11403846153846153
# Val Accuracy/Action(Top 1) 0.025961538461538463
# Epoch : 44
# 0.14577749298840034
# 0.07321242304836831
# Train Accuracy/Verb(Top 1) 0.3835217391304348
# Train Accuracy/Noun(Top 1) 0.1254782608695652
# Train Accuracy/Action(Top 1) 0.03904347826086957
# Val Accuracy/Verb(Top 1) 0.2857692307692308
# Val Accuracy/Noun(Top 1) 0.11365384615384615
# Val Accuracy/Action(Top 1) 0.026153846153846153
# Epoch : 45
# 0.14536395291002785
# 0.0730594013522311
# Train Accuracy/Verb(Top 1) 0.38369565217391305
# Train Accuracy/Noun(Top 1) 0.12560869565217392
# Train Accuracy/Action(Top 1) 0.03908695652173913
# Val Accuracy/Verb(Top 1) 0.2857692307692308
# Val Accuracy/Noun(Top 1) 0.11423076923076923
# Val Accuracy/Action(Top 1) 0.026346153846153846
# Epoch : 46
# 0.14500608153459502
# 0.07267761753826607
# Train Accuracy/Verb(Top 1) 0.3836086956521739
# Train Accuracy/Noun(Top 1) 0.1255217391304348
# Train Accuracy/Action(Top 1) 0.0391304347826087
# Val Accuracy/Verb(Top 1) 0.2878846153846154
# Val Accuracy/Noun(Top 1) 0.11384615384615385
# Val Accuracy/Action(Top 1) 0.02673076923076923
# Epoch : 47
# 0.14521439060932254
# 0.07258874694021737
# Train Accuracy/Verb(Top 1) 0.3849130434782609
# Train Accuracy/Noun(Top 1) 0.1257391304347826
# Train Accuracy/Action(Top 1) 0.03939130434782609
# Val Accuracy/Verb(Top 1) 0.28615384615384615
# Val Accuracy/Noun(Top 1) 0.11346153846153846
# Val Accuracy/Action(Top 1) 0.026346153846153846
# Epoch : 48
# 0.14468826622497744
# 0.0721967282818585
# Train Accuracy/Verb(Top 1) 0.38417391304347825
# Train Accuracy/Noun(Top 1) 0.12569565217391304
# Train Accuracy/Action(Top 1) 0.03930434782608696
# Val Accuracy/Verb(Top 1) 0.28423076923076923
# Val Accuracy/Noun(Top 1) 0.11288461538461539
# Val Accuracy/Action(Top 1) 0.026153846153846153
# Epoch : 49
# 0.14445839509731387
# 0.07227570705297516
# Train Accuracy/Verb(Top 1) 0.38465217391304346
# Train Accuracy/Noun(Top 1) 0.12569565217391304
# Train Accuracy/Action(Top 1) 0.03917391304347826
# Val Accuracy/Verb(Top 1) 0.2871153846153846
# Val Accuracy/Noun(Top 1) 0.11288461538461539
# Val Accuracy/Action(Top 1) 0.025961538461538463
# Epoch : 50
# 0.1444624265519584
# 0.07189857487271471
# Train Accuracy/Verb(Top 1) 0.3853913043478261
# Train Accuracy/Noun(Top 1) 0.1257391304347826
# Train Accuracy/Action(Top 1) 0.03943478260869565
# Val Accuracy/Verb(Top 1) 0.28692307692307695
# Val Accuracy/Noun(Top 1) 0.11307692307692307
# Val Accuracy/Action(Top 1) 0.02653846153846154
# Epoch : 51
# 0.14385938877012672
# 0.07166035611455034
# Train Accuracy/Verb(Top 1) 0.38604347826086954
# Train Accuracy/Noun(Top 1) 0.1257391304347826
# Train Accuracy/Action(Top 1) 0.03939130434782609
# Val Accuracy/Verb(Top 1) 0.28673076923076923
# Val Accuracy/Noun(Top 1) 0.11288461538461539
# Val Accuracy/Action(Top 1) 0.02653846153846154
# Epoch : 52
# 0.1439784214264009
# 0.07166261723855646
# Train Accuracy/Verb(Top 1) 0.3492173913043478
# Train Accuracy/Noun(Top 1) 0.1255217391304348
# Train Accuracy/Action(Top 1) 0.03256521739130435
# Val Accuracy/Verb(Top 1) 0.2569230769230769
# Val Accuracy/Noun(Top 1) 0.11326923076923077
# Val Accuracy/Action(Top 1) 0.02
# Epoch : 53
# 0.14639001401459298
# 0.07163263217705051
# Train Accuracy/Verb(Top 1) 0.3446521739130435
# Train Accuracy/Noun(Top 1) 0.1255217391304348
# Train Accuracy/Action(Top 1) 0.03108695652173913
# Val Accuracy/Verb(Top 1) 0.255
# Val Accuracy/Noun(Top 1) 0.11346153846153846
# Val Accuracy/Action(Top 1) 0.019807692307692307
# Epoch : 54
# 0.1458144833401936
# 0.07145597207836989
# Train Accuracy/Verb(Top 1) 0.3467826086956522
# Train Accuracy/Noun(Top 1) 0.1254782608695652
# Train Accuracy/Action(Top 1) 0.03160869565217391
# Val Accuracy/Verb(Top 1) 0.25403846153846155
# Val Accuracy/Noun(Top 1) 0.11346153846153846
# Val Accuracy/Action(Top 1) 0.019615384615384614
# Epoch : 55
# 0.145825172197528
# 0.07151030883556458
# Train Accuracy/Verb(Top 1) 0.34995652173913044
# Train Accuracy/Noun(Top 1) 0.12534782608695652
# Train Accuracy/Action(Top 1) 0.03208695652173913
# Val Accuracy/Verb(Top 1) 0.25384615384615383
# Val Accuracy/Noun(Top 1) 0.11326923076923077
# Val Accuracy/Action(Top 1) 0.01942307692307692
# Epoch : 56
# 0.14523079816888018
# 0.07146269315626563
# Train Accuracy/Verb(Top 1) 0.3527826086956522
# Train Accuracy/Noun(Top 1) 0.12517391304347827
# Train Accuracy/Action(Top 1) 0.03308695652173913
# Val Accuracy/Verb(Top 1) 0.25653846153846155
# Val Accuracy/Noun(Top 1) 0.11326923076923077
# Val Accuracy/Action(Top 1) 0.019807692307692307
# Epoch : 57
# 0.14492593131414275
# 0.07130256367892754
# Train Accuracy/Verb(Top 1) 0.3538695652173913
# Train Accuracy/Noun(Top 1) 0.12495652173913044
# Train Accuracy/Action(Top 1) 0.03334782608695652
# Val Accuracy/Verb(Top 1) 0.25903846153846155
# Val Accuracy/Noun(Top 1) 0.11307692307692307
# Val Accuracy/Action(Top 1) 0.02
# Epoch : 58
# 0.14468884104635657
# 0.07120212134791584
# Train Accuracy/Verb(Top 1) 0.3551739130434783
# Train Accuracy/Noun(Top 1) 0.12491304347826086
# Train Accuracy/Action(Top 1) 0.03373913043478261
# Val Accuracy/Verb(Top 1) 0.25884615384615384
# Val Accuracy/Noun(Top 1) 0.11288461538461539
# Val Accuracy/Action(Top 1) 0.02
# Epoch : 59
# 0.14391813190971933
# 0.07115227034906062
# Train Accuracy/Verb(Top 1) 0.3567391304347826
# Train Accuracy/Noun(Top 1) 0.12465217391304348
# Train Accuracy/Action(Top 1) 0.03373913043478261
# Val Accuracy/Verb(Top 1) 0.26076923076923075
# Val Accuracy/Noun(Top 1) 0.11307692307692307
# Val Accuracy/Action(Top 1) 0.02076923076923077
# Epoch : 60
# 0.14363430011563186
# 0.07130804323568576
# Train Accuracy/Verb(Top 1) 0.35843478260869566
# Train Accuracy/Noun(Top 1) 0.12434782608695652
# Train Accuracy/Action(Top 1) 0.033869565217391304
# Val Accuracy/Verb(Top 1) 0.26211538461538464
# Val Accuracy/Noun(Top 1) 0.11326923076923077
# Val Accuracy/Action(Top 1) 0.02076923076923077
# Epoch : 61
# 0.143330195764216
# 0.07094598267136551
# Train Accuracy/Verb(Top 1) 0.35995652173913045
# Train Accuracy/Noun(Top 1) 0.12430434782608696
# Train Accuracy/Action(Top 1) 0.03426086956521739
# Val Accuracy/Verb(Top 1) 0.26269230769230767
# Val Accuracy/Noun(Top 1) 0.11365384615384615
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 62
# 0.14310220261899437
# 0.07103616449891068
# Train Accuracy/Verb(Top 1) 0.3601304347826087
# Train Accuracy/Noun(Top 1) 0.1242608695652174
# Train Accuracy/Action(Top 1) 0.03434782608695652
# Val Accuracy/Verb(Top 1) 0.2625
# Val Accuracy/Noun(Top 1) 0.11346153846153846
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 63
# 0.14294713822806754
# 0.07103949298218983
# Train Accuracy/Verb(Top 1) 0.3610434782608696
# Train Accuracy/Noun(Top 1) 0.12417391304347826
# Train Accuracy/Action(Top 1) 0.034782608695652174
# Val Accuracy/Verb(Top 1) 0.2628846153846154
# Val Accuracy/Noun(Top 1) 0.11346153846153846
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 64
# 0.14258522711149077
# 0.07090466814797099
# Train Accuracy/Verb(Top 1) 0.36334782608695654
# Train Accuracy/Noun(Top 1) 0.12408695652173914
# Train Accuracy/Action(Top 1) 0.035130434782608695
# Val Accuracy/Verb(Top 1) 0.2648076923076923
# Val Accuracy/Noun(Top 1) 0.11326923076923077
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 65
# 0.1425174777100726
# 0.07110214320624747
# Train Accuracy/Verb(Top 1) 0.3640434782608696
# Train Accuracy/Noun(Top 1) 0.12408695652173914
# Train Accuracy/Action(Top 1) 0.035260869565217394
# Val Accuracy/Verb(Top 1) 0.2655769230769231
# Val Accuracy/Noun(Top 1) 0.11288461538461539
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 66
# 0.14230212990830585
# 0.0707089430675274
# Train Accuracy/Verb(Top 1) 0.3642173913043478
# Train Accuracy/Noun(Top 1) 0.12391304347826088
# Train Accuracy/Action(Top 1) 0.035173913043478264
# Val Accuracy/Verb(Top 1) 0.265
# Val Accuracy/Noun(Top 1) 0.11269230769230769
# Val Accuracy/Action(Top 1) 0.02
# Epoch : 67
# 0.14221138154588095
# 0.07081596836811159
# Train Accuracy/Verb(Top 1) 0.3644782608695652
# Train Accuracy/Noun(Top 1) 0.1238695652173913
# Train Accuracy/Action(Top 1) 0.035304347826086956
# Val Accuracy/Verb(Top 1) 0.26519230769230767
# Val Accuracy/Noun(Top 1) 0.11269230769230769
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 68
# 0.14182772113055717
# 0.07085270961610282
# Train Accuracy/Verb(Top 1) 0.36517391304347824
# Train Accuracy/Noun(Top 1) 0.12391304347826088
# Train Accuracy/Action(Top 1) 0.035391304347826086
# Val Accuracy/Verb(Top 1) 0.26653846153846156
# Val Accuracy/Noun(Top 1) 0.1123076923076923
# Val Accuracy/Action(Top 1) 0.02
# Epoch : 69
# 0.14179950661775542
# 0.0706992861701221
# Train Accuracy/Verb(Top 1) 0.36517391304347824
# Train Accuracy/Noun(Top 1) 0.12395652173913044
# Train Accuracy/Action(Top 1) 0.035434782608695654
# Val Accuracy/Verb(Top 1) 0.26634615384615384
# Val Accuracy/Noun(Top 1) 0.11211538461538462
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 70
# 0.14198177965675912
# 0.0705480975348775
# Train Accuracy/Verb(Top 1) 0.36543478260869566
# Train Accuracy/Noun(Top 1) 0.12378260869565218
# Train Accuracy/Action(Top 1) 0.035565217391304346
# Val Accuracy/Verb(Top 1) 0.26576923076923076
# Val Accuracy/Noun(Top 1) 0.11192307692307692
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 71
# 0.14188937777426186
# 0.07058840844689346
# Train Accuracy/Verb(Top 1) 0.3658695652173913
# Train Accuracy/Noun(Top 1) 0.12373913043478262
# Train Accuracy/Action(Top 1) 0.035608695652173915
# Val Accuracy/Verb(Top 1) 0.26653846153846156
# Val Accuracy/Noun(Top 1) 0.11173076923076923
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 72
# 0.14160893152399762
# 0.07054088166574153
# Train Accuracy/Verb(Top 1) 0.3660434782608696
# Train Accuracy/Noun(Top 1) 0.12369565217391304
# Train Accuracy/Action(Top 1) 0.035565217391304346
# Val Accuracy/Verb(Top 1) 0.2667307692307692
# Val Accuracy/Noun(Top 1) 0.11173076923076923
# Val Accuracy/Action(Top 1) 0.020576923076923076
# Epoch : 73
# 0.14129307546266695
# 0.0703973741066165
# Train Accuracy/Verb(Top 1) 0.36643478260869566
# Train Accuracy/Noun(Top 1) 0.12373913043478262
# Train Accuracy/Action(Top 1) 0.035608695652173915
# Val Accuracy/Verb(Top 1) 0.26692307692307693
# Val Accuracy/Noun(Top 1) 0.11134615384615384
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 74
# 0.14137224293336637
# 0.07026538289174801
# Train Accuracy/Verb(Top 1) 0.3665217391304348
# Train Accuracy/Noun(Top 1) 0.12365217391304348
# Train Accuracy/Action(Top 1) 0.035391304347826086
# Val Accuracy/Verb(Top 1) 0.2671153846153846
# Val Accuracy/Noun(Top 1) 0.11096153846153846
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 75
# 0.1412898632084451
# 0.07042848802194362
# Train Accuracy/Verb(Top 1) 0.3665652173913043
# Train Accuracy/Noun(Top 1) 0.12352173913043478
# Train Accuracy/Action(Top 1) 0.035434782608695654
# Val Accuracy/Verb(Top 1) 0.26596153846153847
# Val Accuracy/Noun(Top 1) 0.11096153846153846
# Val Accuracy/Action(Top 1) 0.02
# Epoch : 76
# 0.14135872387304538
# 0.07039179147743597
# Train Accuracy/Verb(Top 1) 0.36695652173913046
# Train Accuracy/Noun(Top 1) 0.12343478260869566
# Train Accuracy/Action(Top 1) 0.035478260869565216
# Val Accuracy/Verb(Top 1) 0.2667307692307692
# Val Accuracy/Noun(Top 1) 0.11115384615384616
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 77
# 0.14128208291239855
# 0.07030274519106237
# Train Accuracy/Verb(Top 1) 0.3666086956521739
# Train Accuracy/Noun(Top 1) 0.12334782608695652
# Train Accuracy/Action(Top 1) 0.035347826086956524
# Val Accuracy/Verb(Top 1) 0.2678846153846154
# Val Accuracy/Noun(Top 1) 0.11115384615384616
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 78
# 0.14087370357862333
# 0.07028258130317781
# Train Accuracy/Verb(Top 1) 0.36678260869565216
# Train Accuracy/Noun(Top 1) 0.12321739130434782
# Train Accuracy/Action(Top 1) 0.035304347826086956
# Val Accuracy/Verb(Top 1) 0.26865384615384613
# Val Accuracy/Noun(Top 1) 0.11115384615384616
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 79
# 0.1410826738287763
# 0.07048355079278713
# Train Accuracy/Verb(Top 1) 0.3666086956521739
# Train Accuracy/Noun(Top 1) 0.12317391304347826
# Train Accuracy/Action(Top 1) 0.035173913043478264
# Val Accuracy/Verb(Top 1) 0.26884615384615385
# Val Accuracy/Noun(Top 1) 0.11115384615384616
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 80
# 0.1410992087387457
# 0.0703244529119352
# Train Accuracy/Verb(Top 1) 0.36717391304347824
# Train Accuracy/Noun(Top 1) 0.12308695652173914
# Train Accuracy/Action(Top 1) 0.035173913043478264
# Val Accuracy/Verb(Top 1) 0.26865384615384613
# Val Accuracy/Noun(Top 1) 0.11115384615384616
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 81
# 0.14101224381749222
# 0.07014711281148399
# Train Accuracy/Verb(Top 1) 0.3672608695652174
# Train Accuracy/Noun(Top 1) 0.12308695652173914
# Train Accuracy/Action(Top 1) 0.035217391304347825
# Val Accuracy/Verb(Top 1) 0.26942307692307693
# Val Accuracy/Noun(Top 1) 0.11096153846153846
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 82
# 0.14115359041748976
# 0.07029068499076657
# Train Accuracy/Verb(Top 1) 0.3676521739130435
# Train Accuracy/Noun(Top 1) 0.12304347826086956
# Train Accuracy/Action(Top 1) 0.035260869565217394
# Val Accuracy/Verb(Top 1) 0.2684615384615385
# Val Accuracy/Noun(Top 1) 0.11076923076923077
# Val Accuracy/Action(Top 1) 0.02
# Epoch : 83
# 0.1407395090998673
# 0.07020730012800636
# Train Accuracy/Verb(Top 1) 0.36717391304347824
# Train Accuracy/Noun(Top 1) 0.12295652173913044
# Train Accuracy/Action(Top 1) 0.035304347826086956
# Val Accuracy/Verb(Top 1) 0.2673076923076923
# Val Accuracy/Noun(Top 1) 0.11076923076923077
# Val Accuracy/Action(Top 1) 0.019807692307692307
# Epoch : 84
# 0.14111913457149414
# 0.07001095792142356
# Train Accuracy/Verb(Top 1) 0.367
# Train Accuracy/Noun(Top 1) 0.12291304347826087
# Train Accuracy/Action(Top 1) 0.035304347826086956
# Val Accuracy/Verb(Top 1) 0.26884615384615385
# Val Accuracy/Noun(Top 1) 0.11076923076923077
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 85
# 0.14104688283873767
# 0.06999389383851028
# Train Accuracy/Verb(Top 1) 0.3674782608695652
# Train Accuracy/Noun(Top 1) 0.1228695652173913
# Train Accuracy/Action(Top 1) 0.035173913043478264
# Val Accuracy/Verb(Top 1) 0.2680769230769231
# Val Accuracy/Noun(Top 1) 0.11076923076923077
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 86
# 0.14076203064220708
# 0.07010111910540884
# Train Accuracy/Verb(Top 1) 0.3681304347826087
# Train Accuracy/Noun(Top 1) 0.12282608695652174
# Train Accuracy/Action(Top 1) 0.035086956521739134
# Val Accuracy/Verb(Top 1) 0.26903846153846156
# Val Accuracy/Noun(Top 1) 0.11096153846153846
# Val Accuracy/Action(Top 1) 0.020576923076923076
# Epoch : 87
# 0.14072194564633253
# 0.07000562156118997
# Train Accuracy/Verb(Top 1) 0.3681304347826087
# Train Accuracy/Noun(Top 1) 0.12282608695652174
# Train Accuracy/Action(Top 1) 0.035217391304347825
# Val Accuracy/Verb(Top 1) 0.2701923076923077
# Val Accuracy/Noun(Top 1) 0.11076923076923077
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 88
# 0.140849935717699
# 0.0698006957042508
# Train Accuracy/Verb(Top 1) 0.3676521739130435
# Train Accuracy/Noun(Top 1) 0.12273913043478261
# Train Accuracy/Action(Top 1) 0.035130434782608695
# Val Accuracy/Verb(Top 1) 0.2696153846153846
# Val Accuracy/Noun(Top 1) 0.11076923076923077
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 89
# 0.1410679654377263
# 0.06992035384585217
# Train Accuracy/Verb(Top 1) 0.36769565217391303
# Train Accuracy/Noun(Top 1) 0.12260869565217392
# Train Accuracy/Action(Top 1) 0.035086956521739134
# Val Accuracy/Verb(Top 1) 0.2696153846153846
# Val Accuracy/Noun(Top 1) 0.11038461538461539
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 90
# 0.14076753636685813
# 0.06986173965582033
# Train Accuracy/Verb(Top 1) 0.36769565217391303
# Train Accuracy/Noun(Top 1) 0.12256521739130435
# Train Accuracy/Action(Top 1) 0.035
# Val Accuracy/Verb(Top 1) 0.26884615384615385
# Val Accuracy/Noun(Top 1) 0.11038461538461539
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 91
# 0.14107367091062592
# 0.06976449671314984
# Train Accuracy/Verb(Top 1) 0.368
# Train Accuracy/Noun(Top 1) 0.12234782608695652
# Train Accuracy/Action(Top 1) 0.034739130434782606
# Val Accuracy/Verb(Top 1) 0.2684615384615385
# Val Accuracy/Noun(Top 1) 0.11038461538461539
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 92
# 0.1408019682256187
# 0.06980125358918818
# Train Accuracy/Verb(Top 1) 0.36795652173913046
# Train Accuracy/Noun(Top 1) 0.12234782608695652
# Train Accuracy/Action(Top 1) 0.034782608695652174
# Val Accuracy/Verb(Top 1) 0.2684615384615385
# Val Accuracy/Noun(Top 1) 0.11019230769230769
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 93
# 0.14016157141545924
# 0.0698203823915342
# Train Accuracy/Verb(Top 1) 0.368
# Train Accuracy/Noun(Top 1) 0.12234782608695652
# Train Accuracy/Action(Top 1) 0.034869565217391305
# Val Accuracy/Verb(Top 1) 0.2701923076923077
# Val Accuracy/Noun(Top 1) 0.11019230769230769
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 94
# 0.14047126421114295
# 0.06971065947195379
# Train Accuracy/Verb(Top 1) 0.36882608695652175
# Train Accuracy/Noun(Top 1) 0.12230434782608696
# Train Accuracy/Action(Top 1) 0.034869565217391305
# Val Accuracy/Verb(Top 1) 0.2703846153846154
# Val Accuracy/Noun(Top 1) 0.11019230769230769
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 95
# 0.14084774342978873
# 0.06969839356294492
# Train Accuracy/Verb(Top 1) 0.3686521739130435
# Train Accuracy/Noun(Top 1) 0.1222608695652174
# Train Accuracy/Action(Top 1) 0.034826086956521736
# Val Accuracy/Verb(Top 1) 0.27076923076923076
# Val Accuracy/Noun(Top 1) 0.11
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 96
# 0.1403147950405028
# 0.06985834175493659
# Train Accuracy/Verb(Top 1) 0.368
# Train Accuracy/Noun(Top 1) 0.12230434782608696
# Train Accuracy/Action(Top 1) 0.034652173913043476
# Val Accuracy/Verb(Top 1) 0.2684615384615385
# Val Accuracy/Noun(Top 1) 0.11
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 97
# 0.14063847137660515
# 0.06971757673635716
# Train Accuracy/Verb(Top 1) 0.36778260869565216
# Train Accuracy/Noun(Top 1) 0.12221739130434782
# Train Accuracy/Action(Top 1) 0.034826086956521736
# Val Accuracy/Verb(Top 1) 0.2678846153846154
# Val Accuracy/Noun(Top 1) 0.11
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 98
# 0.14062446922790714
# 0.06981993230377756
# Train Accuracy/Verb(Top 1) 0.3680869565217391
# Train Accuracy/Noun(Top 1) 0.1221304347826087
# Train Accuracy/Action(Top 1) 0.034826086956521736
# Val Accuracy/Verb(Top 1) 0.2698076923076923
# Val Accuracy/Noun(Top 1) 0.11019230769230769
# Val Accuracy/Action(Top 1) 0.020384615384615383
# Epoch : 99
# 0.14028036143721603
# 0.06969866316492965
# Train Accuracy/Verb(Top 1) 0.368
# Train Accuracy/Noun(Top 1) 0.1221304347826087
# Train Accuracy/Action(Top 1) 0.034782608695652174
# Val Accuracy/Verb(Top 1) 0.2692307692307692
# Val Accuracy/Noun(Top 1) 0.11
# Val Accuracy/Action(Top 1) 0.020192307692307693
# Epoch : 100
# 0.1402540304311892
# 0.0696401677480558
# Train Accuracy/Verb(Top 1) 0.3683913043478261
# Train Accuracy/Noun(Top 1) 0.12195652173913044
# Train Accuracy/Action(Top 1) 0.034782608695652174
# Val Accuracy/Verb(Top 1) 0.26942307692307693
# Val Accuracy/Noun(Top 1) 0.10980769230769231
# Val Accuracy/Action(Top 1) 0.020192307692307693
